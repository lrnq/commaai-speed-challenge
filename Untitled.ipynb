# %%
import pandas as pd
import numpy as np

# %%
def batch_shuffle(dframe):
    """
    Randomly shuffle pairs of rows in the dataframe, separates train and validation data
    generates a uniform random variable 0->9, gives 20% chance to append to valid data, otherwise train_data
    return tuple (train_data, valid_data) dataframes
    """
    train_data = pd.DataFrame()
    valid_data = pd.DataFrame()
    for i in range(len(dframe) - 1):
        idx1 = np.random.randint(len(dframe) - 1)
        idx2 = idx1 + 1
        
        row1 = dframe.iloc[[idx1]].reset_index()
        row2 = dframe.iloc[[idx2]].reset_index()

        randInt = np.random.randint(9)
        if 0 <= randInt <= 1:
            valid_frames = [valid_data, row1, row2]
            valid_data = pd.concat(valid_frames, axis = 0, join = 'outer', ignore_index=False)
        if randInt >= 2:
            train_frames = [train_data, row1, row2]
            train_data = pd.concat(train_frames, axis = 0, join = 'outer', ignore_index=False)
    return train_data, valid_data

# %%
df = pd.read_csv('./processed.csv', header = None)

# %%
train, valid = batch_shuffle(df)

# %%
train.shape
# Out:
# (31878, 4)

# %%
train.head()
# Out:
#    index                                           0       1          2
# 0   7446   ./data_preprocessed/372.3500000000504.jpg  372.35  19.664240
# 0   7447   ./data_preprocessed/372.4000000000504.jpg  372.40  19.699236
# 0   9001  ./data_preprocessed/450.10000000006806.jpg  450.10   9.286500
# 0   9002   ./data_preprocessed/450.1500000000681.jpg  450.15   9.349758
# 0   8951   ./data_preprocessed/447.6000000000675.jpg  447.60   9.802236

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
m = cv2.imread(train[0].values[0])
n = Image.open(train[0].values[1])

# %%
plt.imshow(m)

# %%
cv2.destroyAllWindows()

# %%
def change_brightness(image, bright_factor, channel):
    """
    Augments the brightness of the image by multiplying the saturation by a uniform random variable
    Input: image (RGB)
    returns: image with brightness augmentation
    """
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

    # perform brightness augmentation only on the second channel

    hsv_image[:,:,channel] = hsv_image[:,:,channel] * bright_factor



    # change back to RGB
    image_rgb = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)

    return image_rgb, hsv_image

# %%
img0, hsb = change_brightness(m, 2, 2)

# %%
plt.imshow(hsb)

# %%
plt.imshow(img0)

# %%
plt.imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-18f30810e95f> in <module>()
# ----> 1 plt.imshow(img2)
#
# NameError: name 'img2' is not defined
